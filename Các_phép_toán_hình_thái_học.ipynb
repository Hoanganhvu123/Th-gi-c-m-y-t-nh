# %%
import cv2 as cv
import numpy as np
from google.colab.patches import cv2_imshow
img = cv.imread('/content/S2.png',0)
kernel = np.ones((5,5),np.uint8)

# %%
dilation = cv.dilate(img,kernel,iterations = 1)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=770x541 at 0x7FBDAB1D58D0>

# %%
erosion = cv.erode(img,kernel,iterations = 1)
cv2_imshow(erosion)
# Out:
# <PIL.Image.Image image mode=L size=770x541 at 0x7FBDAB1F9B90>

# %%
cv2_imshow(dilation)
# Out:
# <PIL.Image.Image image mode=L size=770x541 at 0x7FBDAB1C7AD0>

# %%
opening = cv.morphologyEx(img, cv.MORPH_OPEN, kernel)
cv2_imshow(opening)
# Out:
# <PIL.Image.Image image mode=L size=770x541 at 0x7FBDAB1D7450>

# %%
closing = cv.morphologyEx(img, cv.MORPH_CLOSE, kernel)
cv2_imshow(closing)
# Out:
# <PIL.Image.Image image mode=L size=770x541 at 0x7FBDAB1C7450>

# %%
gradient = cv.morphologyEx(img, cv.MORPH_GRADIENT, kernel)
cv2_imshow(gradient)
# Out:
# <PIL.Image.Image image mode=L size=770x541 at 0x7FBDAB1D7D10>

# %%
tophat = cv.morphologyEx(img, cv.MORPH_TOPHAT, kernel)
cv2_imshow(tophat)
# Out:
# <PIL.Image.Image image mode=L size=770x541 at 0x7FBDAB1C7B50>

# %%
blackhat = cv.morphologyEx(img, cv.MORPH_BLACKHAT, kernel)
cv2_imshow(blackhat)
# Out:
# <PIL.Image.Image image mode=L size=770x541 at 0x7FBDAB25F2D0>
